# %%
import torch
import torch
import torch.nn as nn
import torch.nn.functional as F
import timm

import torchvision.transforms.functional as TF
from networks.network import MambaCAFU
"""
if __name__ == "__main__":
    # 
    net = MambaCAFU(input_channels=3, num_classes= 9).cuda()

    inp = torch.rand(1,1,224,224).cuda()
    out = net(inp)

    print("out = ",out.shape)
"""    
    
from ptflops import get_model_complexity_info    
with torch.cuda.device(0):
    net = MambaCAFU(input_channels=3, num_classes= 9, version="v2").cuda()
    macs, params = get_model_complexity_info(net, (1, 224, 224), as_strings=True,
                                             print_per_layer_stat=True, verbose=True)
    print('{:<30}  {:<8}'.format('Computational complexity: ', macs))
    print('{:<30}  {:<8}'.format('Number of parameters: ', params))
# Out:
# Start MambaCAFU
# ...
# MambaCAFU(
#   64.33 M, 96.421% Params, 37.91 GMac, 100.000% MACs,
#   (pool): MaxPool2d(0, 0.000% Params, 3.01 MMac, 0.008% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (up): Upsample(0, 0.000% Params, 14.0 MMac, 0.037% MACs, scale_factor=2.0, mode=bilinear)
#   (transformer): FeatureListNet(
#     22.01 M, 32.992% Params, 3.78 GMac, 9.965% MACs,
#     (patch_embed): OverlapPatchEmbed(
#       9.47 k, 0.014% Params, 29.7 MMac, 0.078% MACs,
#       (proj): Conv2d(9.47 k, 0.014% Params, 29.7 MMac, 0.078% MACs, 3, 64, kernel_size=(7, 7), stride=(4, 4), padding=(3, 3))
#       (norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (64,), eps=1e-05, elementwise_affine=True)
#     )
#     (stages_0): PyramidVisionTransformerStage(
#       276.1 k, 0.414% Params, 753.87 MMac, 1.989% MACs,
#       (blocks): ModuleList(
#         276.1 k, 0.414% Params, 753.87 MMac, 1.989% MACs,
#         (0): Block(
# ...
